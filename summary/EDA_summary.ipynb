# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# Our EDA is developed in two parts, business data and review data, since we give recommendations by seperately analyzing these two datasets.

# %% [markdown]
# ## EDA for Business Dataset

# %% [markdown]
# We extract business data of all the mexican restaurants which contain 4628 businesses, and transfer the attributes into dataframe. The percentage of missing of each variable is shown below. For the further analysis, we filter out the variables with more than 90% of missing.

# %% [markdown]
# <div>
# <img src="attachment:missing.png" width="850"/>
# </div>

# %% [markdown]
# For the rest variables, we show their bar plots.

# %% [markdown]
# <div>
# <img src="attachment:stars.png" width="750"/>
# </div>

# %% [markdown]
# From the above plots, we can see that most businesses are rated as 3-4 stars. Most mexican restaurants offer parking but do not offer romantic/intimate/classy ambience.

# %% [markdown]
# <div>
# <img src="attachment:hipster.png" width="750"/>
# </div>

# %% [markdown]
# Most mexican restaurants offer hipster/divey/touristy/trendy/upscale ambience, but more than half of them offer casual ambience.

# %% [markdown]
# <div>
# <img src="attachment:dessert.png" width="750"/>
# </div>

# %% [markdown]
# We can see that most restaurants are good for lunch and dinner, but not good for dessert/latenight/brunch/breakfast.

# %% [markdown]
# <div>
# <img src="attachment:GoodForKids.png" width="750"/>
# </div>

# %% [markdown]
# Most of the mexican restaurants are good for kids and are available to take out and caters. But most of them do not allow reservation.

# %% [markdown]
# <div>
# <img src="attachment:RestaurantsPriceRange2.png" width="750"/>
# </div>

# %% [markdown]
# Most mexican restaurants are not expensive and offer bike parking and TV, but most of them do not have wifi.

# %% [markdown]
# <div>
# <img src="attachment:RestaurantsAttire.png" width="750"/>
# </div>

# %% [markdown]
# Most of the mexican restaurants have casual ambience, are good for groups and wheelchair accessible, accept credit card, and offer parking.

# %% [markdown]
# ## EDA for Review Dataset

# %% [markdown]
# We extract review data of all the mexican restaurants which contain 403941 reviews, and then tokenize the texts. We give some plots to show the information of our review data.

# %% [markdown]
# <div>
# <img src="attachment:star_plot.jpg" width="550"/>
# </div>

# %% [markdown]
# The distribution of stars in mexican restaurants is shown below, we can see that most ratings are five stars.

# %% [markdown]
# <div>
# <img src="attachment:mexi_catplot.jpg" width="450"/>
# </div>

# %% [markdown]
# This plot shows review counts of 5 mexican businesses which have the most reviews. They all have more than 2000 reviews.

# %% [markdown]
# <div>
# <img src="attachment:city_catplot.jpg" width="450"/>
# </div>

# %% [markdown]
# This plot shows review counts of 9 cities which have the most reviews. They all have more than 2000 reviews.

# %% [markdown]
# <div>
# <img src="attachment:wordcloud.jpg" width="650"/>
# </div>

# %% [markdown]
# By the wordcloud, we can see that the most frequent words is chips, salsa, carne asada, etc.

# %% [markdown]
# Some examples which shows the relationship between stars and words in text are shown below.

# %% [markdown]
# <div>
# <img src="attachment:word_distri.png" width="850"/>
# </div>
